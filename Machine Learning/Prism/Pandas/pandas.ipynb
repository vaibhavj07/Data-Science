# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "D:/Important Docs/Knowledge Hut/Machine Learning/Prism/Pandas/data/title.tsv"

# %%
titles = pd.read_csv(path, sep='\t')
# Out:
# c:\users\vaibh\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3524: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
titles
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9304281  tt9916848  tvEpisode              Episode #3.17
# 9304282  tt9916850  tvEpisode              Episode #3.19
# 9304283  tt9916852  tvEpisode              Episode #3.20
# 9304284  tt9916856      short                   The Wind
# 9304285  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# ...

# %%
type(titles)
# Out:
# pandas.core.frame.DataFrame

# %%
list(titles.columns)
# Out:
# ['tconst',
#  'titleType',
#  'primaryTitle',
#  'originalTitle',
#  'isAdult',
#  'startYear',
#  'endYear',
#  'runtimeMinutes',
#  'genres']

# %%
len(titles)
# Out:
# 9304286

# %%
titles.sample(10)
# Out:
#              tconst  titleType             primaryTitle  \
# 9202874   tt9698864  tvEpisode   Kathi lässt es kesseln
# 139218    tt0143528      video             The Luv Game
# 6884626   tt4568938  tvEpisode    23 Bad Business Moves
# 3540914   tt1468749      short                 Untitled
# 756295    tt0780871  tvEpisode              The Surfers
# 2537347  tt12850618      video      Barefoot Debutantes
# 4941482   tt1893236      short                Evolucity
# 1699330  tt11312912  tvEpisode           Luta pelo bolo
# 1184533  tt10390206   tvSeries  Les Z'awards de la télé
# 2177260  tt12173276  tvEpisode           Episode #1.100
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 9202874   Kathi lässt es kesseln       0      2014      \N             \N
# 139218              The Luv Game       1      1988      \N             79
# 6884626    23 Bad Business Moves       0      2015      \N             \N
# ...

# %%
titles[(titles['startYear'] == '1999') &  (titles['titleType'] == 'tvEpisode')].plot.scatter(x='isAdult', y='genres')
# Out:
# <AxesSubplot:xlabel='isAdult', ylabel='genres'>

# %%
titles[titles['primaryTitle'] == 'Hamlet']
# Out:
#             tconst  titleType primaryTitle originalTitle isAdult startYear  \
# 625      tt0000630      movie       Hamlet        Amleto       0      1908
# 626      tt0000631      short       Hamlet        Amleto       0      1908
# 1228     tt0001240      movie       Hamlet        Hamlet       0      1911
# 1229     tt0001241      short       Hamlet        Hamlet       0      1910
# 1230     tt0001242      short       Hamlet        Hamlet       0      1908
# ...            ...        ...          ...           ...     ...       ...
# 8264253  tt7656792  tvEpisode       Hamlet        Hamlet       0      2017
# 8329479  tt7798632      movie       Hamlet        Hamlet       0        \N
# 8391635  tt7934018    tvMovie       Hamlet        Hamlet       0      1983
# 8522853  tt8219328    tvMovie       Hamlet        Hamlet       0      2018
# 9205240  tt9703966      movie       Hamlet        Hamlet       0        \N
#
#         endYear runtimeMinutes genres
# ...

# %%
cent1 = titles[(titles['startYear']>='1900') & (titles['startYear']<='1999')]

# %%
cent1.sort_values(by = ['startYear'])
# Out:
#             tconst  titleType                                    primaryTitle  \
# 157      tt0000160      short                        The Last Days of Pompeii
# 5967080  tt2439632      short    The Special C.I.V. Train Leaving Southampton
# 5967078  tt2439628      short                  Sliding Down an Alpine Glacier
# 330169   tt0344900      short   Battleship 'Odin' with All Her Guns in Action
# 5967077  tt2439626      short  Sir George White Leaving the London Hippodrome
# ...            ...        ...                                             ...
# 538410   tt0559237  tvEpisode                                Murder, My Suite
# 538403   tt0559230  tvEpisode                              Murder on the Hour
# 155179   tt0160298      movie                                        Trippin'
# 7798265  tt6627174  tvEpisode                                   Episode #1.21
# 1647927  tt1121922  tvEpisode                      De verdwenen wetenschapper
#
# ...

# %%
cent1['runtimeMinutes'].replace('\\N', 0, inplace = True)
# Out:
# c:\users\vaibh\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
cent1
# Out:
#             tconst  titleType                             primaryTitle  \
# 157      tt0000160      short                 The Last Days of Pompeii
# 217      tt0000220      short           The Artist and the Flower Girl
# 262      tt0000265      short                          Above the Limit
# 263      tt0000266      short                       Above the Speedway
# 264      tt0000267      short                                L'angélus
# ...            ...        ...                                      ...
# 9304193  tt9916660  tvEpisode            Episode dated 2 February 1993
# 9304229  tt9916738  tvEpisode     Meditation for a Young Boy Confirmed
# 9304230  tt9916740  tvEpisode  From All Saints' Church, Burton Dassett
# 9304231  tt9916742  tvEpisode            From Victoria College, Jersey
# 9304272  tt9916830  tvEpisode                             Episode #2.6
#
#                                    originalTitle isAdult startYear endYear  \
# ...

# %%
cent1['runtimeMinutes'] = pd.to_numeric(cent1['runtimeMinutes'])
# Out:
# c:\users\vaibh\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cent1['runtimeMinutes'].mean()
# Out:
# 18.20353506914428

# %%
titles['runtimeMinutes'].replace('\\N', 0, inplace = True)

# %%
titles['runtimeMinutes'] = pd.to_numeric(titles['runtimeMinutes'])

# %%
titles['startYear'].replace('\\N', 0, inplace = True)

# %%
titles['startYear'] = pd.to_numeric(titles['startYear'])

# %%
titles.nlargest(5, 'startYear')
# Out:
#              tconst  titleType                   primaryTitle  \
# 4850693  tt18412548  tvEpisode                 Back To Normal
# 4850697  tt18412556  tvEpisode                            SMB
# 5789303  tt22498028      movie  Depth of Time: Tsar of Mokusa
# 2122112  tt12072406  tvEpisode                         Hunter
# 2652716  tt13062540      movie                Beakman's Diner
#
#                          originalTitle isAdult  startYear endYear  \
# 4850693                 Back To Normal       0       2029      \N
# 4850697                            SMB       0       2029      \N
# 5789303  Depth of Time: Tsar of Mokusa       0       2029      \N
# 2122112                         Hunter       0       2028      \N
# 2652716                Beakman's Diner       0       2028      \N
#
#          runtimeMinutes genres
# 4850693               0     \N
# 4850697               0     \N
# 5789303               0     \N
# 2122112               0     \N
# 2652716               0     \N

# %%
titles[titles['primaryTitle'] == 'Hamlet'].nlargest(1,'startYear')
# Out:
#              tconst titleType primaryTitle originalTitle isAdult  startYear  \
# 3461206  tt14540788     movie       Hamlet        Hamlet       0       2022
#
#         endYear  runtimeMinutes genres
# 3461206      \N              84     \N
