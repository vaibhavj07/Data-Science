# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://joebiden.com"

# %%
response = requests.get(url)

response.status_code
# Out:
# 200

# %%
url = "https://www.donaldjtrump.com/2024"

# %%
response = requests.get(url)

response.status_code
# Out:
# 200

# %%
url = "https://joebiden.com"

response = requests.get(url)

html_text = response.text

# %%
html_text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US" prefix="og: http://ogp.me/ns#">\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"853c31a225",applicationID:"143000334"};/*! For license information please see nr-loader-rum-1220.min.js.LICENSE.txt */\n!function(t,e){"object"==typeof exports&&"object"==typeof module?module.exports=e():"function"==typeof define&&define.amd?define([],e):"object"==typeof exports?exports.NRBA=e():t.NRBA=e()}(self,(function(){return function(){var t,e,n={9034:function(t,e,n){"use strict";var r=n(4168);e.Z=(0,r.ky)(16)},5973:function(t,e,n){"use strict";n.d(e,{I:function(){return r}});var r=0,o=navigator.userAgent.match(/Firefox[\\/\\s](\\d+\\.\\d+)/);o&&(r=+o[1])},4280:function(t,e,n){"use strict";n.d(e,{H:function(){return o}
# ...

# %%
soup = BeautifulSoup(html_text)

# %%
soup.title
# Out:
# <title>Joe Biden - Official Campaign Page - Joe Biden for President: Official Campaign Website</title>

# %%
soup.title.string
# Out:
# 'Joe Biden - Official Campaign Page - Joe Biden for President: Official Campaign Website'

# %%
text = soup.text

# %%
text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJoe Biden - Official Campaign Page - Joe Biden for President: Official Campaign Website\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate now to help elect Democrats up and down the ballot\nThe Democratic Party is responsible for electing Democrats from the school board to the White House. Rush a donation to invest in the resources that Democrats are relying on to win.\n\n\nThis link leads off-site in a new tab.$10This link leads off-site in a new tab.$25This link leads off-site in a new tab.$75This link leads off-site in a new tab.$150This link leads off-site in a new tab.$250This link leads off-site in a new tab.Other\n\n\n\n\n\n\nSkip to Main Content\n\n\n\n\n\nESThis link leads off-site in a new tab.Donate \n\n\n\n\n\n\n\njoebiden.com home page main content\nLearn more about the Biden administration's accomplishmentsMake calls with the Democ
# ...

# %%
import re

# %%
tokens = re.findall('\w+', text)

# %%
tokens
# Out:
# ['Joe',
#  'Biden',
#  'Official',
#  'Campaign',
#  'Page',
#  'Joe',
#  'Biden',
#  'for',
#  'President',
#  'Official',
#  'Campaign',
#  'Website',
#  'Donate',
#  'now',
#  'to',
#  'help',
#  'elect',
#  'Democrats',
#  'up',
#  'and',
#  'down',
#  'the',
#  'ballot',
#  'The',
#  'Democratic',
#  'Party',
#  'is',
#  'responsible',
#  'for',
#  'electing',
#  'Democrats',
#  'from',
#  'the',
#  'school',
#  'board',
#  'to',
#  'the',
#  'White',
#  'House',
#  'Rush',
#  'a',
#  'donation',
#  'to',
#  'invest',
#  'in',
#  'the',
#  'resources',
#  'that',
#  'Democrats',
#  'are',
#  'relying',
#  'on',
#  'to',
#  'win',
#  'This',
#  'link',
#  'leads',
#  'off',
#  'site',
#  'in',
#  'a',
#  'new',
#  'tab',
#  '10This',
#  'link',
#  'leads',
#  'off',
#  'site',
#  'in',
#  'a',
#  'new',
#  'tab',
#  '25This',
#  'link',
#  'leads',
#  'off',
#  'site',
#  'in',
#  'a',
#  'new',
#  'tab',
#  '75This',
#  'link',
#  'leads',
#  'off',
#  'site',
#  'in',
#  'a',
# ...

# %%
words = []
for word in tokens:
    words.append(word.lower())

# %%
len(words)
# Out:
# 469

# %%
import nltk

# %%
sw = nltk.corpus.stopwords.words('english')

# %%
sw
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
new_words = []

for word in words:
    if word not in sw:
        new_words.append(word)

# %%
len(new_words)
# Out:
# 285

# %%
nlp_words = nltk.FreqDist(new_words)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
nlp_words.plot(20)
plt.show()

# %%
url = "https://www.donaldjtrump.com/2024"

response = requests.get(url)

html_text = response.text

soup = BeautifulSoup(html_text)

text = soup.get_text()

tokens = re.findall('\w+', text)

words = []

for word in tokens:
    words.append(word.lower())
    
sw = nltk.corpus.stopwords.words('english')

new_words = []

for word in words:
    if word not in sw:
        new_words.append(word)
        
nlp_words = nltk.FreqDist(new_words)

nlp_words.plot(20)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
text = " ".join(nlp_words)

# %%
text
# Out:
# 'trump watch president 2024 america official save announcement video 88022 logo phone number calls apply privacy policy joint fundraising committee text merch personally tells running enter info first email cell providing consenting receive sms mms msgs including autodialed automated texts jfc msg data rates may terms conditions txtterms co paid composed authorized donald j pac donaldjtrump com'

# %%
wc = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(text = text)

# %%
plt.figure(figsize=(11,8))
plt.imshow(wc)
